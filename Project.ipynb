# %%
# load GloVe encodings

import tensorflow as tf
import numpy as np

print("Loading word vectors")
embeddings_index = {}
#dct = {}

with open("glove300.txt", 'r') as fh:
    for line in fh:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
        #dct[word] = values[1:]
        

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Loading word vectors
# Found 400000 word vectors.

# %%
# load training data

print("loading training data...")
texts = []
titles = []
subtitles = []
with open('data/NewsArticles.csv', 'rb') as fh:
    lines = fh.readlines()
    #print(len(lines))
    for line in lines[1:129]:  #TODO change me back full dataset
        
        l = str(line)[2:]
        ID, date, link, rest =  l.split(",", 3)
        
        if rest.startswith('"'):
            [scrap, title, rest] = rest.split('"', 2)
        else:
            title, rest = rest.split(",", 1)
        
        if rest.startswith('"'):
            [scrap, subtitle, text] = rest.split('"', 2)
        else:
            subtitle, text = rest.split(",", 1)
        
        text = text.strip(",\\r\\n'")
       
        titles.append(title)
        subtitles.append(subtitle)
        texts.append(text)

num_samples = len(texts)
print("found {} texts".format(num_samples))
print("\n",texts[0])
# Out:
# loading training data...
# found 128 texts
#
#  "Michigan billionaire education activist Betsy DeVos was confirmed today to serve as the secretary of education in President Trump\'s administration, after Vice President Mike Pence cast a tie-breaking vote in the Senate. The Senate voted on DeVos""?highly contentious nomination this afternoon, and the tally was split evenly, requiring Pence to use his authority as president of the upper chamber of Congress to break the impasse. This was the first time that a vice president has broken a tie to confirm a Cabinet nominee. Pence read the vote count 50-50 and then voted himself, rendering the tally 51-50. The day before the vote, Democrats staged a 24-hour marathon of speeches, with more than 30 lawmakers taking to the floor to urge at least one additional Republican to vote against DeVos and block her confirmation. ""It is hard to imagine a worse choice,""?Sen. Elizabeth Warren, D-Mass., said before she read letters from constituents urging her to vote no. DeVos stirred up vehement opposition from teachers""?unions and all 48 Senate Democrats. Many cited concerns about her support of school vouchers, which critics believe will weaken public schools, and her lack of experience, since she never attended or worked in the public education system. Others cited her lack of familiarity with a landmark law protecting the education needs of disabled children.     She was panned for a gaffe during her confirmation hearing, when she hedged on an answer about guns in schools by saying they might be needed in states like Wyoming to defend against ""potential grizzlies.""?DeVos\' nomination drew above-average negative reactions from the public, with voters flooding Senate phone lines and email accounts in recent weeks. Sen. Chris Van Hollen, D-Md., said his office received 14,000 calls about DeVos. In addition to the entire Democratic caucus, two moderate Republicans, Sens. Susan Collins of Maine and Lisa Murkowski of Alaska announced they would not support DeVos. During a speech announcing her opposition, Collins said DeVos""?focus on charters and vouchers ""raises the question of whether or not she fully appreciates that the secretary of education\'s primary focus must be on helping states and communities, parents, teachers, school board members and administrators strengthen our public schools.""?Before the confirmation vote, the Senate Health, Education, Labor and Pensions Committee voted along party lines, 12-11, to refer DeVos""?nomination to the full Senate. ABC News""?Morgan Winsor contributed to this report."

# %%
# convert input sequences into tensors with padding

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

MAX_NUM_WORDS = 1024 # total number of words to work with (most common words from dataset)
MAX_SEQUENCE_LENGTH = 1024
test_percentage = 10

tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts) # list of sequences (one per text input)
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
word_index = tokenizer.word_index  # dictionary mapping words (str) to their rank/index (int)

print('Found %s unique tokens.' % len(word_index))
print('Shape of data tensor:', data.shape)
print("\n", data[1])

# shuffle
#indices = np.arange(data.shape[0])
#np.random.shuffle(indices)
#data = data[indices]

# separate test and training examples
#split = int(num_samples * ((100-test_percentage) / 100))
#res = np.array_split(data, split)
#training_samples = res[0]
#test_samples = res[1]
# Out:
# Found 9938 unique tokens.
# Shape of data tensor: (128, 1024)
#
#  [  0   0   0 ...,   4  35 661]

# %%
# variables

max_len = 1024
hidden_dimension = 300
epochs = 1
learning_rate = 0.01
EMBEDDING_DIM = 300
batch_size = 128

# %%
# compute embedding matrix
from keras.layers import Embedding

embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))

for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        
print(embedding_matrix.shape)
print(embedding_matrix)

# embedding layer

embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            name="Preprocessing",
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False,
                            batch_input_shape=(batch_size, 1024))

#print(embedding_layer.get_config())
# Out:
# (9939, 300)
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.04656     0.21318001 -0.0074364  ...,  0.0090611  -0.20988999
#    0.053913  ]
#  [-0.25756001 -0.057132   -0.67189997 ..., -0.16043     0.046744   -0.070621  ]
#  ...,
#  [-0.34492001 -0.14936    -0.27792001 ..., -0.02331     0.18252    -0.44894999]
#  [ 0.32444    -0.13552999 -0.36107999 ..., -0.33045    -0.072577
#   -0.49854001]
#  [-0.069605    0.052601   -0.22163001 ..., -0.25538     0.14901     0.18018   ]]

# %%
# 2-layer RNN, each layer has 1024 GRU cells
# length of embeddings vectors = 1024
# dropout probability for cells in output layer of first layer = 0.2 
# mini-batch stochastic gradient descent
# anneal the learning rate regularly when validation set fails to improve
# gradients are backpropaged 35 time steps and clipped to max value = 0.25
# formula (2)
from keras.models import Sequential
from keras.layers import GRU, Dropout, Dense, Activation
from keras.optimizers import SGD
from keras.models import load_model

load_from_file = True
if load_from_file:
    model = load_model("saves/model-1513008967.3425572.hdf5")

else:
    dummy_labels = np.zeros((batch_size, 300)) # shouldn't need these

    print('Building STATEFUL model...')
    model = Sequential()
    model.add(embedding_layer)  # input is 2D (samples, indices), output is 3D (samples, sequence_length, embedding_dim)

    # Layer 1
    L1 = GRU(hidden_dimension, name="Layer_1", input_shape=(max_len, 300), return_sequences=True, stateful=True) # unroll=True ?
    #print(L1.get_config())
    model.add(L1)

    # Layer 2
    L2 = GRU(hidden_dimension, name="Layer_2", input_shape=(max_len, 300), return_sequences=False, stateful=True, dropout=0.2)
    model.add(L2)
    # Output logits
    #L3 = Dense(1, name="Logits_layer", activation='softmax')
    #L3 = Activation('softmax')
    #model.add(L3) # outputs result of softmax(dot(input, kernel) + bias)


    print("Input data shape: ", data.shape)
    print("Layer 0 input shape: ", embedding_layer.input_shape)
    print("Layer 0 output shape: ", embedding_layer.output_shape)
    print("Layer 1 input shape: ", L1.input_shape)
    print("Layer 1 output shape: ", L1.output_shape)
    print("Layer 2 input shape: ", L2.input_shape)
    print("Layer 2 output shape: ", L2.output_shape)




    #model.add(Dropout(0.2))
    #model.add(GRU(hidden_dimension, input_shape=(max_len, 300), return_sequences=False, stateful=False))
    #model.add(Dense(1024, activation='softmax')) # preds

    sgd = SGD(learning_rate, momentum=0.0, decay=0.0, nesterov=False)
    model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

    # train
    output = model.fit(data, dummy_labels, batch_size=batch_size, epochs=epochs, shuffle=False)

    import time
    now = int(time.time())
    model.save("saves/model-{}.hdf5".format(str(now)))
    
print("\n", model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Preprocessing (Embedding)    (128, 1024, 300)          2981700
# _________________________________________________________________
# Layer_1 (GRU)                (128, 1024, 300)          540900
# _________________________________________________________________
# Layer_2 (GRU)                (128, 300)                540900
# =================================================================
# Total params: 4,063,500
# Trainable params: 1,081,800
# Non-trainable params: 2,981,700
# _________________________________________________________________
#
#  None

# %%
# Re-define model for predictions with batch size 1

n_batch = 1
new_model = Sequential()

new_embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            name="Preprocessing_new",
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False,
                            batch_input_shape=(n_batch, 1024))

new_model.add(new_embedding_layer)  # input is 2D (samples, indices), output is 3D (samples, sequence_length, embedding_dim)

# Layer 1
new_L1 = GRU(hidden_dimension, name="Layer_1_new", input_shape=(max_len, 300), return_sequences=True, stateful=True) # unroll=True ?
new_model.add(new_L1)

# Layer 2
new_L2 = GRU(hidden_dimension, name="Layer_2_new", input_shape=(max_len, 300), return_sequences=False, stateful=True, dropout=0.2)
new_model.add(new_L2)

sgd = SGD(learning_rate, momentum=0.0, decay=0.0, nesterov=False)

# copy weights
old_weights = model.get_weights()
new_model.set_weights(old_weights)
new_model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])
print("done")
# Out:
# done

# %%
# make predictions 
# do beam search here instead

import keras.preprocessing.text

print("input: ", data[0])
prediction = new_model.predict(np.array(data[0])[np.newaxis])[0]
print("prediction: ", prediction)

items_iterator = embeddings_index.items()
inverse_dictionary = dct #{v: k for k, v in items_iterator}

word_vectors = embeddings_index.values()

dst = (np.dot(word_vectors, prediction)
               / np.linalg.norm(word_vectors, axis=1)
               / np.linalg.norm(prediction))

word_ids = np.argsort(-dst)

x = prediction
print([(inverse_dictionary[x], dst[x]) for x in word_ids[:5] if x in self.inverse_dictionary])
# Out:
# input:  [  0   0   0 ...,   2  29 150]
# prediction:  [ 0.04572431  0.01570713  0.05382569 -0.11145879  0.1462418   0.04722214
#  -0.04859181 -0.10704654 -0.09107925 -0.01094797 -0.10073339 -0.04246584
#   0.13497752 -0.10365248 -0.23515652 -0.13684878 -0.20667528  0.00721037
#   0.17974156 -0.15897979  0.14913592  0.14937566  0.01850339  0.11201054
#   0.2268997  -0.14638424 -0.20244944  0.24165636  0.36174268  0.04289497
#  -0.00321247 -0.09621538 -0.01938743 -0.03167554 -0.17574283  0.14660315
#  -0.05914986 -0.06970091 -0.10216457  0.0587291   0.0356455  -0.008211
#  -0.22130033 -0.04675016 -0.11456672 -0.10555627 -0.09474204 -0.04943121
#   0.14787239 -0.11926004  0.06533959  0.27145827 -0.21120021 -0.07077575
#   0.00621931 -0.071443    0.09603091  0.1817199   0.17582867 -0.00249821
#  -0.05660181  0.27953646 -0.05721919  0.2707743   0.06069357 -0.16527149
#  -0.16364256  0.0371842  -0.26538384 -0.04680658 -0.03583626 -0.04456161
#   0.14272247  0.05205672 -0.20102808  0.02758783 -0.06952568  0.17310834
#   0.128957    0.22907948  0.12762934  0.16587779  0.09894659  0.27822176
#  -0.05862916  0.08336861  0.02883911  0.06394457  0.22497085 -0.10092807
#   0.18964681 -0.12086632 -0.07793348 -0.07368658 -0.11572463  0.06163947
#  -0.13763407  0.05439957 -0.00257985  0.01644555  0.12344936  0.09290269
#  -0.05649763 -0.07749885 -0.03798461 -0.12273023  0.02894497 -0.02702772
#   0.06382199 -0.05981364 -0.1299084   0.00362715 -0.05591824 -0.11891319
#   0.11413597  0.04188897 -0.01016873 -0.00384288  0.03481609 -0.25461724
#   0.1066803  -0.09378323 -0.00711472 -0.06986503 -0.08852756  0.04128344
#  -0.01722727  0.08720706 -0.06215423 -0.05398004 -0.03876815 -0.17082426
#  -0.05908665 -0.08169021 -0.0863748   0.02849126 -0.02997102 -0.25289303
#   0.01639672  0.05430655  0.01283736 -0.089827   -0.05394506  0.02123901
#  -0.0815226   0.05946349  0.00070652  0.20086846  0.10941684 -0.17455083
#  -0.09817962 -0.04951236  0.06481856  0.03692434  0.03405733 -0.01363943
#  -0.10456346  0.00343941  0.20266762  0.06309525 -0.05179825  0.06666106
#   0.0098431   0.12450676 -0.30792814 -0.26879027  0.0208529   0.03986145
#  -0.23663327 -0.07276427  0.05747048  0.02093035  0.05913327 -0.12839624
#   0.08835046  0.17050532  0.11943638 -0.12075428 -0.43983847  0.10977934
#  -0.20992379 -0.16244416 -0.02887086  0.05603391 -0.00174179 -0.17729595
#   0.07562609  0.12581679 -0.1663762   0.25329852 -0.06729602 -0.02973879
#  -0.02137953  0.13790545 -0.0189357  -0.00916217  0.19860417 -0.0426424
#   0.13844988 -0.19014046  0.01100269 -0.06133977  0.06146131  0.25675946
#  -0.05337143  0.13091192  0.04462605 -0.11742167 -0.07575701  0.04135511
#  -0.06779113 -0.1720435  -0.03206792 -0.18093458 -0.20149747 -0.06646974
#  -0.34563684 -0.16379514  0.03535838 -0.07223048 -0.04909878  0.0395952
#   0.11088604  0.00073295  0.07671575  0.17489369 -0.01131769  0.11366959
#  -0.01906598 -0.24778405  0.09214786  0.05384031  0.07672949 -0.04449886
#   0.0414627   0.21402359  0.09249873  0.03907951 -0.04640493  0.11970417
#  -0.16945423 -0.16211611 -0.07202426 -0.06563301  0.08995283 -0.24161002
#  -0.05063313  0.0332876   0.14327455 -0.07097208  0.09577765  0.25941321
#  -0.34656397 -0.04084239  0.00453077  0.07451372  0.01749424  0.18562397
#   0.08946995 -0.11894825  0.07221947 -0.05603735 -0.04290498 -0.17474893
#  -0.04554316  0.10468653 -0.02009897  0.2209042   0.16392319  0.02447106
#  -0.18020083 -0.09987836 -0.02462383 -0.06188898 -0.00785645 -0.06677273
#   0.1347044  -0.23788556  0.0608625   0.09636193  0.17552909  0.05014561
#   0.08043443  0.0302769   0.15190613 -0.23998088 -0.19424212 -0.05346512
#   0.16896388  0.03416946 -0.17401257  0.11276577 -0.00741473  0.04871307
#   0.02209225  0.00461047 -0.11623894 -0.04167836 -0.12922482  0.05272946]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e979749629f9> in <module>()
#      15 dst = (np.dot(word_vectors, prediction)
#      16                / np.linalg.norm(word_vectors, axis=1)
# ---> 17                / np.linalg.norm(prediction))
#      18
#      19 word_ids = np.argsort(-dst)
#
# TypeError: unsupported operand type(s) for *: 'dict_values' and 'float'

# %%
# beam search decoder
sequence_length=1024

decoded, log_prob = tf.nn.ctc_beam_search_decoder(
    output,
    sequence_length,
    beam_width=8,
    top_paths=1,
    merge_repeated=True
)

#K.get_value(dec[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     489                 as_ref=input_arg.is_ref,
# --> 490                 preferred_dtype=default_dtype)
#     491           except TypeError as err:
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     675         if ret is None:
# --> 676           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     677
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     120   _ = as_ref
# --> 121   return constant(v, dtype=dtype, name=name)
#     122
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     101   tensor_value.tensor.CopyFrom(
# --> 102       tensor_util.make_tensor_proto(value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     103   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     375     else:
# --> 376       _AssertCompatible(values, dtype)
#     377       nparray = np.array(values, dtype=np_dt)
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/tensor_util.py in _AssertCompatible(values, dtype)
#     301       raise TypeError("Expected %s, got %s of type '%s' instead." %
# --> 302                       (dtype.name, repr(mismatch), type(mismatch).__name__))
#     303
#
# TypeError: Expected float32, got <keras.callbacks.History object at 0x7f4132f51358> of type 'History' instead.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-234335410403> in <module>()
#       8     beam_width=8,
#       9     top_paths=1,
# ---> 10     merge_repeated=True
#      11 )
#      12
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/ctc_ops.py in ctc_beam_search_decoder(inputs, sequence_length, beam_width, top_paths, merge_repeated)
#     267       gen_ctc_ops._ctc_beam_search_decoder(
#     268           inputs, sequence_length, beam_width=beam_width, top_paths=top_paths,
# --> 269           merge_repeated=merge_repeated))
#     270
#     271   return (
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/gen_ctc_ops.py in _ctc_beam_search_decoder(inputs, sequence_length, beam_width, top_paths, merge_repeated, name)
#      62                                 sequence_length=sequence_length,
#      63                                 beam_width=beam_width, top_paths=top_paths,
# ---> 64                                 merge_repeated=merge_repeated, name=name)
#      65   return _CTCBeamSearchDecoderOutput._make(result)
#      66
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     497                   "type '%s' instead." %
#     498                   (dtypes.as_dtype(dtype).name, input_arg.name, op_type_name,
# --> 499                    repr(values), type(values).__name__))
#     500           except ValueError:
#     501             # What type does convert_to_tensor think it has?
#
# TypeError: Expected float32 passed to parameter 'inputs' of op 'CTCBeamSearchDecoder', got <keras.callbacks.History object at 0x7f4132f51358> of type 'History' instead.

# %%
# use reverse of word_index.items() to lookup words from integer ID

def keras_rnn_predict(samples, empty=0, rnn_model=new_model):
    """for every sample, calculate probability for every possible label
    you need to supply your RNN model and maxlen - the length of sequences it can handle
    """
    res = []
    inputs = pad_sequences(samples, maxlen=MAX_SEQUENCE_LENGTH)
    for i in inputs:
        res.append(rnn_model.predict(np.array(i)[np.newaxis], verbose=0))
    
    return np.array(res)

def beamsearch(predict=keras_rnn_predict, k=8, maxsample=400, use_unk=False, oov=None, empty=1, eos="eos"):
    """return k samples (beams) and their NLL scores, each sample is a sequence of labels,
    all samples starts with an `empty` label and end with `eos` or truncated to length of `maxsample`.
    You need to supply `predict` which returns the label probability of each sample.
    `use_unk` allow usage of `oov` (out-of-vocabulary) label in samples
    """
    
    dead_k = 0 # samples that reached eos
    dead_samples = []
    dead_scores = []
    live_k = 1 # samples that did not yet reached eos
    live_samples = [[empty]]
    live_scores = [0]

    while live_k and dead_k < k:
        # for every possible live sample calc prob for every possible label 
        probs = predict(live_samples, empty=empty)

        # total score for every sample is sum of -log of word prb
        cand_scores = np.array(live_scores)[:,None] - np.log(probs)
        if not use_unk and oov is not None:
            cand_scores[:,oov] = 1e20
        cand_flat = cand_scores.flatten()

        # find the best (lowest) scores we have from all possible samples and new words
        ranks_flat = cand_flat.argsort()[:(k-dead_k)]
        live_scores = cand_flat[ranks_flat]

        # append the new words to their appropriate live sample
        voc_size = probs.shape[1]
        live_samples = [live_samples[r//voc_size]+[r%voc_size] for r in ranks_flat]

        # live samples that should be dead are...
        zombie = [s[-1] == eos or len(s) >= maxsample for s in live_samples]
        
        # add zombies to the dead
        dead_samples += [s for s,z in zip(live_samples,zombie) if z]  # remove first label == empty
        dead_scores += [s for s,z in zip(live_scores,zombie) if z]
        dead_k = len(dead_samples)
        # remove zombies from the living 
        live_samples = [s for s,z in zip(live_samples,zombie) if not z]
        live_scores = [s for s,z in zip(live_scores,zombie) if not z]
        live_k = len(live_samples)

    return dead_samples + live_samples, dead_scores + live_scores 

print(beamsearch())

# %%
# encode


# 2-layer RNN, each layer has 1024 GRU cells
# length of embeddings vectors = 1024
# dropout probability for cells in output layer of first layer = 0.2 
# mini-batch stochastic gradient descent
# anneal the learning rate regularly when validation set fails to improve
# gradients are backpropaged 35 time steps and clipped to max value = 0.25
# formula (2)

from keras.models import Sequential
from keras.layers import GRUCell
from keras.layers import RNN
from keras.optimizers import SGD
from keras.layers import Input
import keras

learning_rate = 1 #0.01 #1e-6
clip_norm = 1.0 # ???


sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)


# Model
#model = Sequential()

# Cells
layer_one_cells = []
for _ in range(0, 1024):
    layer_one_cells.append(GRUCell(300, activation='tanh', recurrent_activation='hard_sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', dropout=0.2, recurrent_dropout=0.0))

layer_two_cells = []  
for _ in range(0, 1024):
    layer_two_cells.append(GRUCell(300, activation='tanh', recurrent_activation='hard_sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros'))

                           
# Layers
#one = RNN(layer_one_cells, return_sequences=False, return_state=False, go_backwards=False, stateful=False, unroll=False)
#two = RNN(layer_two_cells, return_sequences=False, return_state=False, go_backwards=False, stateful=False, unroll=False)

inputs = keras.Input((60, 300))
one = keras.layers.RNN(layer_one_cells)(inputs)
#two = keras.layers.RNN(layer_two_cells)(inputs)

model = keras.models.Model(inputs, one)

#model.add(embedding_layer)
#model.add(one)
#model.add(two)



#rnn.add(GRU(1024, activation='tanh', recurrent_activation='hard_sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', dropout=0.0, recurrent_dropout=0.0))

sgd = SGD(learning_rate, momentum=0.0, decay=0.0, nesterov=False)

model.compile(loss='mse',
            optimizer=sgd,
            metrics=['accuracy'])

model.fit(embedded_sequences, None, epochs=1, batch_size=1024, verbose=2)

#scores = rnn.evaluate(x_test, y_test, verbose=0)
#print('IRNN test score:', scores[0])
#print('IRNN test accuracy:', scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-bb85a5597c28> in <module>()
#      43
#      44 inputs = keras.Input((60, 300))
# ---> 45 one = keras.layers.RNN(layer_one_cells)(inputs)
#      46 #two = keras.layers.RNN(layer_two_cells)(inputs)
#      47
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     480
#     481         if initial_state is None and constants is None:
# --> 482             return super(RNN, self).__call__(inputs, **kwargs)
#     483
#     484         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     601
#     602             # Actually call the layer, collecting output(s), mask(s), and shape(s).
# --> 603             output = self.call(inputs, **kwargs)
#     604             output_mask = self.compute_mask(inputs, previous_mask)
#     605
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     587                                              mask=mask,
#     588                                              unroll=self.unroll,
# --> 589                                              input_length=timesteps)
#     590         if self.stateful:
#     591             updates = []
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length)
#    2554
#    2555         time_steps = tf.shape(inputs)[0]
# -> 2556         outputs, _ = step_function(inputs[0], initial_states + constants)
#    2557         output_ta = tensor_array_ops.TensorArray(
#    2558             dtype=outputs.dtype,
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/layers/recurrent.py in step(inputs, states)
#     578         else:
#     579             def step(inputs, states):
# --> 580                 return self.cell.call(inputs, states, **kwargs)
#     581
#     582         last_output, outputs, states = K.rnn(step,
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/layers/recurrent.py in call(self, inputs, states, **kwargs)
#      84         new_nested_states = []
#      85         for cell, states in zip(self.cells, nested_states):
# ---> 86             inputs, states = cell.call(inputs, states, **kwargs)
#      87             new_nested_states.append(states)
#      88
#
# ~/Code/ML/tensorflow/lib/python3.5/site-packages/keras/layers/recurrent.py in call(self, inputs, states, training)
#    1307         if self.implementation == 1:
#    1308             if 0. < self.dropout < 1.:
# -> 1309                 inputs_z = inputs * dp_mask[0]
#    1310                 inputs_r = inputs * dp_mask[1]
#    1311                 inputs_h = inputs * dp_mask[2]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-2a102e6a3a24> in <module>()
# ----> 1 ctc_beam_search_decoder(
#       2     inputs,
#       3     sequence_length,
#       4     beam_width=100,
#       5     top_paths=1,
#
# NameError: name 'ctc_beam_search_decoder' is not defined

# %%
texts = []
with open('data/NewsArticles.csv', 'rb') as fh:
    lines = fh.readlines()
    #print(len(lines))
    for line in lines:
        
        l = str(line)[2:]
        ID, date, link, rest =  l.split(",", 3)
        
        if rest.startswith('"'):
            [scrap, title, rest] = rest.split('"', 2)
        else:
            title, rest = rest.split(",", 1)
        
        if rest.startswith('"'):
            [scrap, subtitle, text] = rest.split('"', 2)
        else:
            subtitle, text = rest.split(",", 1)
        
        text = text.strip(",\\r\\n'")
       
        print(title)
        texts.append(text)
    #print(ID, date, link, title) 
    #print(subtitle, text)
# Out:
# title
# Betsy DeVos Confirmed as Education Secretary, With Pence Casting Historic Tie-Breaking Vote
# Melania Trump Says White House Could Mean Millions for Brand
# As Trump Fears Fraud, GOP Eliminates Election Commission
# Appeals Court to Decide on Challenge to Trump\'s Immigration Executive Order
# Climate skeptic advisor says Trump could pull out of Paris climate agreement in days
# What is carbon monoxide poisoning?
# Can a deposit system help reusable coffee cups catch on?
# Why some wild hamsters become crazed cannibals
# When boxer crabs fight, anemones are the real winners
# Love tequila? Then raise your glass to bats
# Antibiotics can boost bacterial growth
# Earthworm numbers dwindle, threatening soil health
# Meet the German movement to transform agriculture
# Opinion: Trump\'s America is beginning to look a lot like China
# Will Israel annex Palestinian territories?
# Jovenel Moise sworn in as Haiti\'s new president
# Scotland rejects triggering Brexit in non-binding vote
# Land grab law \'allows theft, stalls peace process\'
# Afghan refugees\' status extended until end of year
#
# NewsGrid - Al Jazeera\'s interactive news hour
# Nicolas Sarkozy to be tried over 2012 campaign funding
# Explaining the Somali election process
# Suicide blast near Kabul Supreme Court kills dozens
# Intense raids kill dozens in Syria\'s Idlib
# Somalia beefs up security ahead of presidential vote
# Ayatollah Khamenei: Donald Trump shows real face of US
#
# Winter storm hits northwestern US
# Israeli settlement law \'violates rights and dignity\' Nigel Wilson
# Revisiting Yahya Jammeh
# \'In our village, ISIL executed hundreds of people \'
#
# Israeli torture of Palestinian children \'institutional\' Ben White
# Geert Wilders tweets fake picture of rival
# Yakla residents speak of US raid that killed civilians
# Israel approves controversial settlement expansion bill
# Israeli strikes on Gaza Strip injure three Palestinians
# Syria\'s Civil War Explained
# Brexit uncertainty? It\'s the luck of the Irish
# CSIC fueling major marine technology
# Provinces push for structural reforms
# Capacity cuts aim to take heat off coal
# Confidence to be a top priority
# Consumption remains key driver
# Quotable
# Mobike works with Foxconn to expand fleet
# Fixed investment growth rate declines
# Internet fund aims to boost innovation
# French business chiefs look forward to forum
# IPO surge may lower stock prices
# CIMC Enric pioneering international gas transport
# IN BRIEF (Page 24)
# Racing ahead with the motoring elite
# Chinese law firm Yingke goes beyond routine legal help
# To Russia with energetic love
# Measure of change
# When rooster makes a call
# Reunion of the Year
# Holiday sales are a sign of the ancient times
# The (r) evolution of an internet celebrity
# China must cut its wasteful ways
# From a young age, a ticket to a dream role in paradise
# Air pollution concerns potential overseas talent
# Festival demand soars for fake friends
# Be cautious, China urges the US
# New child policy increases births
# Beijing, Manila agree on $3.7b in shared projects
# Smoggy New Year
# Democracy or humility? Why not both?
# Ranking China\'s global brand builders
# China could withstand a trade war
# Momentum gives hope in a challenging year
# Controlling the looming economic risks
# Quotable
# IN BRIEF (Page 2)
# Gearing up
# Highs and lows of living in paradise
# China could help make America great again
# Mexico\'s losses could be China\'s gains
# Returning to the US? It\'s a non-starter
# Quotable
# Baidu Inc unveils augmented reality lab
# Product aims to boost meat production
# IN BRIEF (Page 24)
# SinoFortone aims to be household name in UK
# New faces in banking
# Dependence on foreign oil up
# Next target is to cut costs, make machines locally
# Share prices of SOEs expected to \'bounce back\'
# Payment agencies told to bank clients\' cash
# Churning out milk from grass to the glass
# Cheers to the beer that conquered the world
# The write stuff: Chinese pens reach tipping point
# Brewer optimistic about growth
# \'China\'s destiny was to lead the world\'
# Woman fights to popularize Eileen Chang in English
# Endangered species make up new focus
# Open the gates
# Internet-based thriller draws fans to theaters
# Yoga lessons aim to tackle student stress
# Cozying up to the Kitchen God
# Lonesome lives: The sad plight of children left behind by workers seeking a better life in China\'s cities
# Melancholy life of teenager who must fend for herself
# Plastic surgery could give Hubei man second chance
# Digital economy invents new job fields
# Xinjiang to invest huge amount in road network
# Father of pinyin writing system dies at age 111
# Look at history to see the future
# Don\'t drag out the Blue Monday blues
# Those investing overseas must consider risks
# Famous folk can\'t resist a tasty sound bite
# Azerbaijan forms a key link in the Silk Road chain
# Fintech will help boost real economy
# Quotable
# IN BRIEF (Page 2)
# Silk Road investment to link public, private growth
# Jackie Chan\'s Indian adventure
# Just what Europe wanted to hear
# China\'s philosophy of mutual benefits coherent with Davos
# China\'s contribution to the global economy
# US could lose its imaginary war
# A breath of fresh air
# Nokia phone may struggle in China
# Riding out the perfect storm
# China bids to lure more investment
# Young, diverse, innovative and female
# Ma tells Trump \'I\'ll create 1m jobs in US\'
# Bank\'s proud record of financial prowess
# Quotable
# Bank warns of bitcoin volatility
# IN BRIEF (Page 24)
# Report lists fastest-growing companies
# Chinese app developers come of age
# Yuan steadies as central bank\'s remedies take hold
# Subsidy cut puts brakes booming on car sales
# Chinese writers make global splash
# A dumpling for every season
# The land of cold and gold
# A dish full of history
# Company has grand designs on the world
# The big picture
# Awards recognize China\'s innovators
# Clean-up drive for disciplinary teams
# Sports authority proposes cap on football salaries
# IN BRIEF (Page 12)
# Quotable
# It\'s common sense in any language
# Pandas are cute, but spare a thought for red cousin
# 2017 bodes well for Chinese takeovers
# On the road again
# State visit to enhance ties with Switzerland
# By working together, we\'ll create better world
# A glimpse of the future
# Federer has advantage with Chinese fans
# Sino-Swiss links are in peak condition
# Supply-side reform good recipe for fixing economy
# Calm voice emerges from global turmoil
# Factory of the future: Clean, high-tech
# Xi expected to bring a steady voice to Davos
# Investment helps promote global recovery
# Xi to send signal against protectionism
# Foreign links key to future success
# Roses have scent of money
# Warning of tight times ahead for insurers
# Weaker yuan is a double-edged sword
# Quotable
# IN BRIEF (Page 24)
# Old electronics mean new opportunities for company
# Profit growth key for Huawei
# Fund aims to be a long-term investor
# Chinese giant makes inroads into the UK\'s infrastructure
# E-commerce set to boost traditional enterprises
# CNPC in running for Iran energy projects
# Mining a rich urban resource - discarded batteries
# Domestic buyers a key real estate driver
# Belt, Road study nears completion
# Service sector shows continued expansion
# It\'s critical to go fast on digital highway
# Startups prove there\'s a lot of money in muck
# The curing month
# Hit and myth: the movie monsters lost in translation
# Two-child policy poses risks for older women
# You know where you are with province names
# Building a giant reputation
# Cleaner, greener - and becoming richer
# At Stanford, fairway is classroom
# Stamps set to mark Year of Rooster
# $503b earmarked for high-speed railway plan
# Xi insists on \'strictest\' control over food safety
# New sectors are opening up to foreign investors
# Innovation requires tolerance of failure
# Open, frequent exchanges will foster better UK ties
# Stop capital flight by reducing taxes
# Even men can suffer from domestic violence
# Focus shifts from growth to structure
# British railways have run out of steam
# Ivory trade ban key to saving elephants
# Quotable
# IN BRIEF (Page 2)
# \'Our exhaustion is worth it\'
# Data tamperers face tough penalties
# Sculpting China\'s changing seasons
# Taking a breath of fresh air
# Residents\' feedback pinpoints the polluters
# How to achieve more with less in business
# Quotable
# Coal-to-liquid venture delivers first shipment
# China\'s FTZs sharpening their competitive edge
# Office sharing gives startups a leg up
# Long stock correction may end in 2017
# Chinese business school spreads its global perspective
# IN BRIEF (Page 24)
# WeChat calls beat telecom companies
# TCL Corp took global strategy to heart early
# A river that flows with local culture
# Three days in Shanghai
# Changing the subject
# Timeless Chinese BBQ
# Ethnic art inspires high fashion
# Outbound investment expected to grow
# China looks to export its stealth fighter
# Two bullet train lines now connect southwest to coast
# TCM law promotes traditional health practice
# Africa\'s open road to development
# 2017 will be the Year of Chinese Consumers
# Smog in the air, but green is on the horizon
# E-commerce holds plenty of surprises
# Britain\'s health service is a gem. I should know.
# Superior tech, stronger brands needed
# China walks its own path to prosperity
# Cheap Chinese solar panels are good
# IN BRIEF (Page 2)
# Quotable
# Change to what?
# There but for the presence of China ...
# A story of deadly torrents and tears
# New year will be marked by change
# A land shaped by water\'s ebb and flow
# IN BRIEF (Page 24)
# The language of luxury
# Property developers set to ride out market turbulence
# X-lab nurtures the future for China, Germany
# Chint Group expands through offshore deals
# Recruiting overseas needs knack for diversity
# Quotable
# Earthquake opened door for telecom giant
# Wanda chief: China must create channels for culture export
# Gasoline, diesel prices rise
# Luxury homes get smaller as property prices go up
# Real estate prices settling into stable pattern
# Chinese overseas investment patterns evolving
# UnionPay cards expanding globally
# What\'s up with the money, doc?
# Goodall: Our brains can save us
# At Taoist resort, peace prevails
# Fanning the flames of obsession
# Longest night, tastiest feast
# Singing has stayed in tune with the times
# Beijing, Paris agree to enhance pursuit of fugitives
# Family seeks payout over executed son
# Chinese math teaching buoys British schools
# China to integrate its data resources
# Is this the road to a more stable future?
# China edging more into tech value chain
# Financial creativity crucial for East Africa
# Trump may find tough sledding ahead
# Virtual reality will never make you a traveler
# Smog has a silver lining for scientists
# Quotable
# IN BRIEF (Page 2)
# Song apps provide a new stage for fame
# Give China its due; stop the protectionism
# Breaking with globalization is ill-advised
# One answer to punitive West: Upgrade steel
# As protectionism rises, China may face new problems
# Keep your promises
# Expanding on a fast track
# What gets Harley chief\'s motor running
# The British link
# ZTE expands with 48% stake in Turkey telecom
# Airlines to take direct hit from rising price of oil
# Insurers are thinking big on overseas investing
# Levitating and hurtling toward a breakthrough
# IN BRIEF (Page 24)
# Alipay gets warm welcome in Santa\'s hometown
# Buying a luxury car? Pay 10% surtax
# Forex reserves decline by 2.2% in November
# Ex-WTO chief lauds China\'s trade
# OPEC cut likely to affect upstream sectors
# Copenhagen to co-host 2018 Design Week
# China-UK dual degrees now within easier reach
# Quotable
# Proceed with caution, guru warns
# Of good deeds and online fog
# Village revival
# Building character
# Season for chestnuts!
# Old man\'s brew tickles young
# Stick to the rules. Witch rules?
# Executed man found not guilty
# Sierra Leone recovers with \'help of friend\'
# Party briefs EU on its anti-graft initiative
# Parents wanted to live long enough to clear son
# Factory makes special cups for autistic teen
# New day for traditional medicine
# Connecting to investors\' needs
# Deliver us from these robot postmen
# Why Ivanka Trump is joining the Trump administration
# Two survive after plane crashes in sea at Shoreham
# David Tennant to sue over News of the World phone-hacking
# Syrian opposition\'s Moscow group says forming united delegation would be logical
# Russian ambassador urges NATO to abandon military domination policy
# Three Russian cities interested in hosting 2023 Basketball World Championship
# White House gives no specific dates for Russian-US summit
# United Arab Emirates shows interest in Russian helicopters
# NATO secretary general says ceasefire in Donbass works only on paper
# Russia keeps forming strong anti-doping legislative basis in sports, deputy PM says
# Putin not against Russian businessman Deripaska speaking to US Congress about Manafort
# Russian space rocket center receives first tested engines for Soyuz spacecraft
# Ukrainian president orders to implement ceasefire starting from April 1
# Kremlin critic Kara-Murza: Protests a \'turning point\' for Western stance on Russia
# Tillerson\'s first Turkey visit ends in impasse as US shifts position on Assad
# Airlines offer workaround for US laptop ban
# Britain sets out \'Great Repeal Bill\' plan to transform thousands of EU laws
# Schalke\'s Nabil Bentaleb: \'Nobody gave me the chance until I arrived here\'
# Sieren\'s China: Balkans without borders
# \'Read my lips: no!\' Putin chooses a peculiar quote and then bungles it
# DRC crisis worsens as UN mulls MONUSCO\'s mandate
# German firms back off from building Trump\'s border wall
# Germany\'s top court rules parents must betray children in piracy cases
# Venezuela Supreme Court assumes Congress role
# Chios: Syrian refugee critical after \'self-immolation\'
# Court approves warrant for ex-leader Park\'s arrest
# Syria: Kurdish YPG fighters dominate Turkey-US talks
# UN: Number of Syrian refugees passes five million
# 118 foreign detainees \'die\' in Malaysia in two years
# The US-Mexico border wall: What\'s at stake? Massoud Hayoun
# Fighters blow themselves up with grenade in Bangladesh
# North Korea-Malaysia deal ends diplomatic spat
#
#
# Ethiopia extends state of emergency by four months
# Egypt \'one of the biggest prisons for journalists\'
# Nigeria summons Indian ambassador over student attacks
# Subscribe to our new podcast, Al Jazeera Out Loud
# Al Jazeera reporter spends 100th day in Egyptian jail
# Israel: The house of hate Stanley L Cohen
# Infographic: What is land day?
# British government takes next steps towards Brexit
#
#
# The Gambia\'s missing sons and daughters Hamza Mohamed
# India\'s Ladycops
# Welsh helicopter crash victims were members of same family
# Clarity from garda\xa8\xaa on bonus payments
# Brexit secretary denies threat over security co-operation
# Boy who suffered injuries at birth awarded \x801.5m
# South Korea\'s ousted president arrested
# SDLP leader hopeful NI talks will resume next week
# Appeal for woman missing from Kilkenny
# Kim Jong Nam\'s body released to North Korea
# Dublin girl gets magical wonderland wish granted
# \'Neither did Jesus please everyone\' - Ronaldo sculptor happy
# Grenoble lifts suspension against rugby players
# PAC chair says he was pressured to limit Project Eagle report
# Funeral of Danielle McLaughlin takes place in Donegal
# High Court endorses Ian Bailey European Arrest Warrant
# Bus ?ireann warns rural school transport payments \'may be delayed\'
# 12 applications for representation at Disclosures Tribunal
# Conditions preventing attempts to lift Rescue 116 wreckage
# Children in Northern Ireland eating treble recommended sugar intake
# Call for United Nations disabilities convention to be ratified
# Carrickmines victims died of carbon monoxide poisoning, inquest hears

# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text"
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.

source: https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import GRU
from keras.optimizers import SGD
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

#path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()

text = " ".join(texts)
print('corpus length:', len(text))


chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Using TensorFlow backend.
# corpus length: 12808990
# total chars: 94
# nb sequences: 4269650
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(GRU(1024, input_shape=(maxlen, len(chars))))#, dropout=0.2)
model.add(GRU(1024, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

#optimizer = RMSprop(lr=0.01)
sgd = SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import SimpleRNN
from keras import initializers
from keras.optimizers import RMSprop

batch_size = 32
num_classes = 10
epochs = 50
hidden_units = 100

learning_rate = 1e-6
clip_norm = 1.0

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], -1, 1)
x_test = x_test.reshape(x_test.shape[0], -1, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print('Evaluate IRNN...')
model = Sequential()
model.add(SimpleRNN(hidden_units,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
rmsprop = RMSprop(lr=learning_rate)
model.compile(loss='categorical_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test, verbose=0)
print('IRNN test score:', scores[0])
print('IRNN test accuracy:', scores[1])
# Out:
# x_train shape: (60000, 784, 1)
# 60000 train samples
# 10000 test samples
# Evaluate IRNN...
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 426s 7ms/step - loss: 2.1069 - acc: 0.2092 - val_loss: 1.9923 - val_acc: 0.2543
# IRNN test score: 1.99227425728
# IRNN test accuracy: 0.2543

# %%
# length model
length_model = Sequential()

# %%
# repetition model
repetition_model = Sequential()

# %%
# ...

# %%
# entailment model
# rate=0.0005, batch size=128
#tf.train.AdamOptimizer
entailment_model = Sequential()

# %%
# relevance model
# train with ADAM (rate=0.001, dropout=0.5)
# 1-D convolution layer with filter size 3, stride 1
# pad sequences so that output is same length as input

# %%
# scrap

# 2-layer RNN, each layer has 1024 GRU cells
"""
units_per_layer = 1024
units_per_cell = 1024 # maybe should be 300?
layer_one_dropout = 0.2

#learning_rate = 1 # find init value, anneal

layer_one_cells = []
layer_two_cells = []

for _ in range(0, units_per_layer):
    cell = tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.GRUCell(units_per_cell), output_keep_prob=1.0-layer_one_dropout)
    layer_one_cells.append(cell)

for _ in range(0, units_per_layer):
    cell = tf.contrib.rnn.GRUCell(units_per_cell)
    layer_two_cells.append(cell)
    
first = tf.contrib.rnn.MultiRNNCell(layer_one_cells)
second = tf.contrib.rnn.MultiRNNCell(layer_two_cells)

# TODO connect layers
"""

# %%
# embed words into 300-D vectors initialized with GloVe encodings
# embedding_matrix is a tensor of shape [vocabulary_size, embedding size] => [?????, 300]

word_embeddings = tf.nn.embedding_lookup(vectors, word_ids)  # returns A Tensor with the same type as the tensors in params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c90f15826ea3> in <module>()
#       2 # embedding_matrix is a tensor of shape [vocabulary_size, embedding size] => [?????, 300]
#       3
# ----> 4 word_embeddings = tf.nn.embedding_lookup(vectors, word_ids)  # returns A Tensor with the same type as the tensors in params
#
# NameError: name 'word_ids' is not defined
